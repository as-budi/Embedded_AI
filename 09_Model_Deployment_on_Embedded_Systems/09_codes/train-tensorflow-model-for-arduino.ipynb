# %%
! pip install "everywhereml>=0.2.32"

# %%
"""
Get X and y data
(replace with your own)
"""
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler


def load_Xy():
  """
  Load your data here.
  It may be a CSV file or whatever
  """
  return load_iris(return_X_y=True)


def get_Xy():
  """
  Normalize X
  One-hot encode y
  """
  X, y = load_Xy()
  X = np.asarray(X)
  y = np.asarray(y)
  num_classes = y.max()
  eye = np.eye(num_classes + 1)
  X_norm = MinMaxScaler().fit_transform(X)
  y_hot = np.asarray([eye[yi] for yi in y], dtype=int)

  return X_norm, y_hot

# %%
"""
Instantiate NN for classification
Replace with your own topology
"""
import tensorflow as tf
from tensorflow.keras import layers


def instantiate_nn_for_classification(input_shape, num_classes):
  model = tf.keras.Sequential()
  model.add(layers.Dense(32, activation='relu', input_shape=input_shape))
  model.add(layers.Dense(16, activation='relu'))
  model.add(layers.Dense(num_classes, activation='softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  return model

# %%
"""
Split data between train, validation and test
"""
from sklearn.model_selection import train_test_split


X, y = get_Xy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3)

# %%
"""
Train model
"""
input_shape = X.shape[1:]
num_classes = y.shape[1]

model = instantiate_nn_for_classification(input_shape, num_classes)
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1320 - accuracy: 0.0137 - val_loss: 1.1148 - val_accuracy: 0.1562
# Epoch 2/50
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0998 - accuracy: 0.3973 - val_loss: 1.0843 - val_accuracy: 0.5000
# Epoch 3/50
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0712 - accuracy: 0.7123 - val_loss: 1.0561 - val_accuracy: 0.7812
# Epoch 4/50
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0449 - accuracy: 0.7671 - val_loss: 1.0305 - val_accuracy: 0.8750
# Epoch 5/50
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0211 - accuracy: 0.7534 - val_loss: 1.0058 - val_accuracy: 0.8750
# Epoch 6/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9975 - accuracy: 0.7260 - val_loss: 0.9845 - val_accuracy: 0.8750
# Epoch 7/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9767 - accuracy: 0.7397 - val_loss: 0.9655 - val_accuracy: 0.8750
# Epoch 8/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9578 - accuracy: 0.7260 - val_loss: 0.9459 - val_accuracy: 0.8125
# Epoch 9/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9412 - accuracy: 0.6164 - val_loss: 0.9273 - val_accuracy: 0.8125
# Epoch 10/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9240 - accuracy: 0.6027 - val_loss: 0.9098 - val_accuracy: 0.8125
# Epoch 11/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9068 - accuracy: 0.6164 - val_loss: 0.8913 - val_accuracy: 0.8125
# Epoch 12/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8885 - accuracy: 0.6438 - val_loss: 0.8717 - val_accuracy: 0.8438
# Epoch 13/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8688 - accuracy: 0.7671 - val_loss: 0.8510 - val_accuracy: 0.8438
# Epoch 14/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8480 - accuracy: 0.8219 - val_loss: 0.8311 - val_accuracy: 0.9375
# Epoch 15/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8275 - accuracy: 0.9178 - val_loss: 0.8098 - val_accuracy: 0.9375
# Epoch 16/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8063 - accuracy: 0.9178 - val_loss: 0.7879 - val_accuracy: 0.9375
# Epoch 17/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7864 - accuracy: 0.9041 - val_loss: 0.7647 - val_accuracy: 0.9375
# Epoch 18/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7660 - accuracy: 0.8630 - val_loss: 0.7442 - val_accuracy: 0.9375
# Epoch 19/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7482 - accuracy: 0.9315 - val_loss: 0.7257 - val_accuracy: 0.9375
# Epoch 20/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7283 - accuracy: 0.9315 - val_loss: 0.7045 - val_accuracy: 0.9375
# Epoch 21/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7103 - accuracy: 0.9041 - val_loss: 0.6846 - val_accuracy: 0.9375
# Epoch 22/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.9178 - val_loss: 0.6679 - val_accuracy: 0.9375
# Epoch 23/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6754 - accuracy: 0.9315 - val_loss: 0.6476 - val_accuracy: 0.9375
# Epoch 24/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6578 - accuracy: 0.9315 - val_loss: 0.6280 - val_accuracy: 0.9375
# Epoch 25/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6409 - accuracy: 0.9178 - val_loss: 0.6105 - val_accuracy: 0.9375
# Epoch 26/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6239 - accuracy: 0.9452 - val_loss: 0.5953 - val_accuracy: 0.9062
# Epoch 27/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6080 - accuracy: 0.9452 - val_loss: 0.5792 - val_accuracy: 0.9062
# Epoch 28/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5933 - accuracy: 0.9452 - val_loss: 0.5626 - val_accuracy: 0.9062
# Epoch 29/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.9452 - val_loss: 0.5478 - val_accuracy: 0.9062
# Epoch 30/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.9452 - val_loss: 0.5335 - val_accuracy: 0.9062
# Epoch 31/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5500 - accuracy: 0.9452 - val_loss: 0.5212 - val_accuracy: 0.8750
# Epoch 32/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.9452 - val_loss: 0.5099 - val_accuracy: 0.8750
# Epoch 33/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5247 - accuracy: 0.9452 - val_loss: 0.4975 - val_accuracy: 0.8750
# Epoch 34/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.9178 - val_loss: 0.4870 - val_accuracy: 0.8750
# Epoch 35/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5016 - accuracy: 0.9452 - val_loss: 0.4738 - val_accuracy: 0.8750
# Epoch 36/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4903 - accuracy: 0.9589 - val_loss: 0.4617 - val_accuracy: 0.9062
# Epoch 37/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4805 - accuracy: 0.9452 - val_loss: 0.4510 - val_accuracy: 0.9375
# Epoch 38/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.9589 - val_loss: 0.4395 - val_accuracy: 0.9375
# Epoch 39/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4611 - accuracy: 0.9589 - val_loss: 0.4307 - val_accuracy: 0.9375
# Epoch 40/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.9589 - val_loss: 0.4246 - val_accuracy: 0.9375
# Epoch 41/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.9315 - val_loss: 0.4204 - val_accuracy: 0.8750
# Epoch 42/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4347 - accuracy: 0.9452 - val_loss: 0.4121 - val_accuracy: 0.9062
# Epoch 43/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4268 - accuracy: 0.9589 - val_loss: 0.4057 - val_accuracy: 0.8750
# Epoch 44/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4190 - accuracy: 0.9589 - val_loss: 0.3968 - val_accuracy: 0.9375
# Epoch 45/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.9452 - val_loss: 0.3931 - val_accuracy: 0.8750
# Epoch 46/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4035 - accuracy: 0.9452 - val_loss: 0.3899 - val_accuracy: 0.8750
# Epoch 47/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3973 - accuracy: 0.9589 - val_loss: 0.3875 - val_accuracy: 0.8750
# Epoch 48/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3902 - accuracy: 0.9315 - val_loss: 0.3836 - val_accuracy: 0.8750
# Epoch 49/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3823 - accuracy: 0.9315 - val_loss: 0.3742 - val_accuracy: 0.8750
# Epoch 50/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3750 - accuracy: 0.9726 - val_loss: 0.3614 - val_accuracy: 0.9375

# %%
"""
Export NN to C++
Copy-paste the generated code inside a file named model.h or irisModel.h
in your Arduino project
"""
from everywhereml.code_generators.tensorflow import convert_model


c_header = convert_model(model, X, y, model_name='irisModel')
print(c_header)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/qg/vb_4ypx91kvfzw2t50q5sb9h0000gn/T/tmphv6qa76g/assets
# INFO:tensorflow:Assets written to: /var/folders/qg/vb_4ypx91kvfzw2t50q5sb9h0000gn/T/tmphv6qa76g/assets
# 2025-04-29 05:02:46.543351: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# #pragma once
#
# #ifdef __has_attribute
# #define HAVE_ATTRIBUTE(x) __has_attribute(x)
# #else
# #define HAVE_ATTRIBUTE(x) 0
# #endif
# #if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))
# #define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))
# #else
# #define DATA_ALIGN_ATTRIBUTE
# #endif
#
# // automatically configure network
# #define TF_NUM_INPUTS 4
# #define TF_NUM_OUTPUTS 3
# #define TF_NUM_OPS 2
# #define TF_OP_FULLYCONNECTED
# #define TF_OP_SOFTMAX
#
#
#
#
# // sample data
# float x0[4] = {0.22222222222f, 0.62500000000f, 0.06779661017f, 0.04166666667f};
# float x1[4] = {0.75000000000f, 0.50000000000f, 0.62711864407f, 0.54166666667f};
# float x2[4] = {0.55555555556f, 0.54166666667f, 0.84745762712f, 1.00000000000f};
#
#
# /** model size = 5052 bytes **/
# const unsigned char irisModel[] DATA_ALIGN_ATTRIBUTE = { , 0 ...
# 2025-04-29 05:02:46.543469: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2025-04-29 05:02:46.543942: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /var/folders/qg/vb_4ypx91kvfzw2t50q5sb9h0000gn/T/tmphv6qa76g
# 2025-04-29 05:02:46.544525: I tensorflow/cc/saved_model/reader.cc:91] Reading meta graph with tags { serve }
# 2025-04-29 05:02:46.544530: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /var/folders/qg/vb_4ypx91kvfzw2t50q5sb9h0000gn/T/tmphv6qa76g
# 2025-04-29 05:02:46.546347: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2025-04-29 05:02:46.546960: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2025-04-29 05:02:46.577036: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /var/folders/qg/vb_4ypx91kvfzw2t50q5sb9h0000gn/T/tmphv6qa76g
# 2025-04-29 05:02:46.584974: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 41033 microseconds.
# 2025-04-29 05:02:46.606546: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
